# %%
# Importing useful Libraries
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Loading data into dataFrames from files
match_data = pd.read_excel(r"C:\Users\dines\OneDrive\Desktop\projects\IPL team selection\DIM_MATCH.xlsx")
player_data = pd.read_csv(r"C:\Users\dines\OneDrive\Desktop\projects\IPL team selection\DIM_PLAYER (3).csv",encoding='latin1')
player_match_data = pd.read_csv(r"C:\Users\dines\OneDrive\Desktop\projects\IPL team selection\DIM_PLAYER_MATCH.csv",encoding='latin1')
batting_stats2022=pd.read_csv(r"C:\Users\dines\OneDrive\Desktop\projects\IPL team selection\Batting Stats\BATTING STATS - IPL_2022.csv")
batting_stats2016=pd.read_csv(r"C:\Users\dines\OneDrive\Desktop\projects\IPL team selection\Batting Stats\BATTING STATS - IPL_2016.csv")
bowling_stats2016=pd.read_csv(r"C:\Users\dines\OneDrive\Desktop\projects\IPL team selection\Bowling Stats\BOWLING STATS - IPL_2016.csv")
bowling_stats2022=pd.read_csv(r"C:\Users\dines\OneDrive\Desktop\projects\IPL team selection\Bowling Stats\BOWLING STATS - IPL_2022.csv")

# %%
# finding null or missing values in match_data set
match_data.isnull().sum()
# Out:
# Match_SK        0
# match_id        0
# Team1           0
# Team2           0
# match_date      0
# Season_Year     0
# Venue_Name      1
# City_Name       0
# Country_Name    0
# Toss_Winner     1
# match_winner    3
# Toss_Name       1
# Win_Type        2
# Outcome_Type    0
# ManOfMach       4
# Win_Margin      9
# Country_id      0
# dtype: int64

# %%
# handling with missing and irrelevent values in match_data
match_data.dropna(inplace=True)
match_data.drop(['Match_SK','Win_Margin','ManOfMach','Outcome_Type','Win_Type','Toss_Name','Toss_Winner','match_date'],axis=1,inplace=True)

# %%
#finding null values in player_data
player_data.isnull().sum()
# Out:
# PLAYER_SK         0
# Player_Id         0
# Player_Name       0
# DOB               0
# Batting_hand      0
# Bowling_skill    46
# Country_Name      0
# dtype: int64

# %%
# handling with missing values
player_data['Bowling_skill'].fillna('Missing',inplace=True)

# %%
# dropping irrelavent column( it will not be used in team selection)
player_data.drop(['DOB','PLAYER_SK'],axis=1,inplace=True)
player_data
# Out:
#      Player_Id        Player_Name    Batting_hand        Bowling_skill  \
# 0            1         SC Ganguly   Left-hand bat     Right-arm medium
# 1            2        BB McCullum  Right-hand bat     Right-arm medium
# 2            3         RT Ponting  Right-hand bat     Right-arm medium
# 3            4          DJ Hussey  Right-hand bat   Right-arm offbreak
# 4            5    Mohammad Hafeez  Right-hand bat   Right-arm offbreak
# ..         ...                ...             ...                  ...
# 492        493        T Natarajan   Left-hand bat      Left-arm medium
# 493        494       Tejas Baroka  Right-hand bat      Legbreak googly
# 494        495           TS Mills  Right-hand bat        Left-arm fast
# 495        496       Vishnu Vinod  Right-hand bat              Missing
# 496        497  Washington Sundar   Left-hand bat   Right-arm offbreak
#
#     Country_Name
# 0          India
# 1    New Zealand
# 2      Australia
# 3      Australia
# 4       Pakistan
# ...

# %%
# finding null values in player_match_data
player_match_data.isnull().sum()
# Out:
# Player_match_SK           0
# PlayerMatch_key           0
# Match_Id                  0
# Player_Id                 0
# Player_Name               1
# DOB                       1
# Batting_hand              1
# Bowling_skill          1131
# Country_Name              1
# Role_Desc                 1
# Player_team               1
# Opposit_Team              1
# Season_year               1
# is_manofThematch          1
# Age_As_on_match           1
# IsPlayers_Team_won        1
# Batting_Status        13993
# Bowling_Status        13993
# Player_Captain            1
# Opposit_captain           1
# Player_keeper             1
# Opposit_keeper            1
# dtype: int64

# %%
# handling with missing and irrelavent data
player_match_data.drop(['Player_match_SK','DOB',"Batting_Status","Bowling_Status",'PlayerMatch_key','Role_Desc','Age_As_on_match'],axis=1,inplace=True)

player_match_data['Bowling_skill'].fillna('Missing',inplace=True)

player_match_data.dropna(inplace=True)
player_match_data
# Out:
#        Match_Id  Player_Id        Player_Name     Batting_hand  \
# 1        335987          6           R Dravid   Right-hand bat
# 2        335987          7           W Jaffer   Right-hand bat
# 3        335987          8            V Kohli   Right-hand bat
# 4        335987          9          JH Kallis   Right-hand bat
# 5        335987         10           CL White   Right-hand bat
# ...         ...        ...                ...              ...
# 13988   1082650        413          KH Pandya    Left-hand bat
# 13989   1082650        430            A Zampa   Right-hand bat
# 13990   1082650        483        LH Ferguson   Right-hand bat
# 13991   1082650        488        RA Tripathi   Right-hand bat
# 13992   1082650        497  Washington Sundar    Left-hand bat
#
#                 Bowling_skill  Country_Name                  Player_team  \
# 1          Right-arm offbreak         India  Royal Challengers Bangalore
# ...

# %%
# finding missing values in batting_stats2022
batting_stats2022.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
# finding missing values in bowling_stats2022
bowling_stats2022.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# Ov        0
# Runs      0
# Wkts      0
# BBI       0
# Avg       0
# Econ      0
# SR        0
# 4w        0
# 5w        0
# dtype: int64
